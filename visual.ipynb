# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_2020 = pd.read_excel(r"2020.xlsx")
raw_2021 = pd.read_excel(r"2021.xlsx")
raw_2022 = pd.read_excel(r'2022.xlsx')

# %%
raw
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                           [데이터 설명]
# 1          NaN                                                컬렴명
# 2          NaN                                                학교명
# 3          NaN                                                 지역
# 4          NaN                                                교육청
# 5          NaN                                               설립유형
# 6          NaN                                                학교급
# 7          NaN                                              사고자구분
# 8          NaN                                              사고자성별
# 9          NaN                                              사고자학년
# 10         NaN                                              사고접수일
# 11         NaN                                              사고발생일
# 12         NaN                                             사고발생요일
# 13         NaN                                             사고발생시간
# 14         NaN                                               사고시간
# 15         NaN                                               사고장소
# 16         NaN                                               사고부위
# 17         NaN                                               사고형태
# 18         NaN                                              사고매개물
# 19         NaN                                             사고당시활동
# 20         NaN  * 학교학교안전사고보상지원시스템 : 학교안전공제중앙회에서 운영하는 사고접수 및 보상...
#
#                                            Unnamed: 2  \
# 0                                                 NaN
# 1                                                  설명
# 2                            학교안전사고보상지원시스템* 내 등록된 학교명
# 3                                          학교가 소속된 지역
# 4                                         학교가 소속된 교육청
# 5                                            학교 설립 유형
# 6                                                 학교급
# 7                                              사고자 구분
# 8                                              사고자 성별
# 9                                              사고자 학년
# 10                          학교안전사고보상지원시스템에 사고를 접수한 날짜
# 11                                         사고가 발생한 날짜
# 12                                         사고가 발생한 요일
# 13                                         사고가 발생한 시간
# 14  학교안전사고보상지원시스템 사고 접수 시, \n선택한 사고 항목["(참고)사고유형별 항목]
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                            Unnamed: 3  \
# 0                                                 NaN
# 1                                           항목(가나다 순)
# 2                                                  -
# 3                                                  -
# 4                                                  -
# 5                                          공립, 국립, 사립
# 6   고등학교, 기타학교*, 유치원, 중학교, 초등학교, 특수학교\n* 기타학교 : (고...
# 7   교육활동참여자, 교직원(계약직), 교직원(교원), 교직원(일반직), 기타(일반인 등...
# 8                                                남, 녀
# 9               1학년, 2학년, 3학년, 4학년, 5학년, 6학년, 유아, N/A
# 10                                                 -
# 11                                                 -
# 12                                                 -
# 13                                                 -
# 14  기숙사생활, 기타, 등하교, 석식시간, 수업시간, 점심시간, 체육수업, 특별활동, ...
# 15                            교실, 교외활동, 부속시설, 운동장, 통로
# 16         기타, 다리, 머리(두부), 발, 복합부위, 손, 치아(구강), 팔, 흉복부
# 17      기타, 낙상-넘어짐, 낙상-떨어짐, 낙상-미끄러짐, 물리적힘 노출, 사람과의 충돌
# 18  가구(책상/의자/책장/탁자/침대 등), 건물(문/창문/바닥/벽 등), 기계 도구류(...
# 19   공부, 구기운동, 기타, 기타운동, 보행/주행, 식사/수면/휴식, 실험실습, 장난/놀이
# 20                                                NaN
#
#                                            Unnamed: 4
# 0                                                 NaN
# 1                                                  비고
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                           중앙회 데이터 집계 기준은 사고접수일 기준임
# 11  해당연도 사고 접수일 기준 데이터이므로 \n사고 발생연도는 해당연도 외 다른 연도 ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
